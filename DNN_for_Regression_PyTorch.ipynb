# %% [markdown]
# <a href="https://colab.research.google.com/github/Tar-ive/dl_basics/blob/main/DNN_for_Regression_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
torch.manual_seed(42)
X = torch.rand(1000,2) * 10 # 1000 data points with 2 features
y = (X[:,0] + X[:,1] * 2).unsqueeze(1) + torch.randn(1000,1) # Introducing non-linear relationship with random noise in the data

# %%
# Writing the DNN Class

class DNNModel(nn.Module):
  def __init__(self):
    super().__init__()
    self.net = nn.Sequential(
        nn.Linear(2, hidden_dim),
        nn.ReLU(),
        nn.Linear(hidden_dim, 1) # since output will be for a single unit for regression
    )
  def forward(self, x):
    return self.net(x)

# %%
# Initialize Model, Loss, and Optimizer
hidden_dim = 100
model = DNNModel()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr = 0.01)

# Training Loop
epochs = 10000
for epoch in range(epochs):
  #Forward Pass
  predictions = model(X)
  loss = criterion(predictions, y)

  #Backward pass and optimizer
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

  #Log Progress every 100 epochs
  if (epoch + 1) % 100 == 0:
    print(f"Epoch: {epoch + 1}, Loss: {loss}")


#Testing on new data
X_test =torch.tensor([[4.0, 3.0], [7.0, 8.0]])
with torch.no_grad():
  predictions = model(X_test)
  print(f"Predictions for {X_test.tolist()}: {predictions.tolist()}")
# Out:
# Epoch: 100, Loss: 1.0191895961761475
# Epoch: 200, Loss: 0.9830608367919922
# Epoch: 300, Loss: 0.9735357165336609
# Epoch: 400, Loss: 0.9703795909881592
# Epoch: 500, Loss: 0.968963623046875
# Epoch: 600, Loss: 0.9680672883987427
# Epoch: 700, Loss: 0.9675261974334717
# Epoch: 800, Loss: 0.9669443368911743
# Epoch: 900, Loss: 0.966026782989502
# Epoch: 1000, Loss: 0.9644112586975098
# Epoch: 1100, Loss: 0.9628186225891113
# Epoch: 1200, Loss: 0.961592435836792
# Epoch: 1300, Loss: 0.9607167840003967
# Epoch: 1400, Loss: 0.9600629806518555
# Epoch: 1500, Loss: 0.9596030712127686
# Epoch: 1600, Loss: 0.9590080976486206
# Epoch: 1700, Loss: 0.9585303664207458
# Epoch: 1800, Loss: 0.9578723907470703
# Epoch: 1900, Loss: 0.9572861194610596
# Epoch: 2000, Loss: 0.9568200707435608
# Epoch: 2100, Loss: 0.9563577175140381
# Epoch: 2200, Loss: 0.9558884501457214
# Epoch: 2300, Loss: 0.9552577137947083
# Epoch: 2400, Loss: 0.9544473886489868
# Epoch: 2500, Loss: 0.9539393186569214
# ...
