# %% [markdown]
# <a href="https://colab.research.google.com/github/Tar-ive/dl_basics/blob/main/Byte_Pair_Encoding_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import defaultdict, Counter

def get_vocab(corpus):
  """Creates a vocabulary with words split into characters and a special end of word token."""
  vocab = Counter()
  for word in corpus:
    tokens = list(word) + [""]
    vocab[tuple(tokens)]+=1
  return vocab

def get_stats(vocab):
  """Counts frequency of adjacent symbol pairs."""
  pairs = defaultdict(int)
  for word,freq in vocab.items():
    for i in range(len(word)-1):
      pairs[(word[i], word[i+1])] +=freq
  return pairs

def merge_vocab(pair, vocab):
  """Merges the most frequent pair into a single symbol."""
  new_vocab = {}
  bigram = ' '.join(pair)
  replacement = ''.join(pair)
  print(f"Bigram: {bigram}")
  for word,freq in vocab.items():
    word_str = ' '.join(word)
    #Replace bigram with merged symbol
    new_word_str=word_str.replace(bigram, replacement)
    #Preserve the trailing empty string token if the original word ended with it
    tokens = new_word_str.split()
    if word[-1] == "":
      tokens.append("")
    new_vocab[tuple(tokens)]=freq
  return new_vocab


def byte_pair_encoding(corpus, num_merges=10):
  """Performs BPE on a corpus."""
  vocab = get_vocab(corpus)
  merges = []
  for _ in range(num_merges):
    pairs = get_stats(vocab)
    if not pairs:
      break
    best = max(pairs, key=pairs.get)
    vocab = merge_vocab(best, vocab)
    merges.append(best)
    print(f"Merge {_ + 1}: {best}")
  return vocab, merges

corpus = ["low", "lowest", "newer", "wider", "owl", "LOW"]
final_vocab , merge_operations = byte_pair_encoding(corpus, num_merges=10)
# vocab = get_vocab(corpus)
# pairs = get_stats(vocab)
# print(pairs)
# new_vocab = merge_vocab(pairs, vocab)
print("\nFinal Vocabulary:")
for word in final_vocab:
  print("".join(word), ":", final_vocab[word])
# Out:
# Bigram: o w
# Merge 1: ('o', 'w')
# Bigram: l ow
# Merge 2: ('l', 'ow')
# Bigram: e r
# Merge 3: ('e', 'r')
# Bigram: er
# Merge 4: ('er', '')
# Bigram: er
# Merge 5: ('er', '')
# Bigram: er
# Merge 6: ('er', '')
# Bigram: er
# Merge 7: ('er', '')
# Bigram: er
# Merge 8: ('er', '')
# Bigram: er
# Merge 9: ('er', '')
# Bigram: er
# Merge 10: ('er', '')
#
# Final Vocabulary:
# low : 1
# lowest : 1
# newer : 1
# wider : 1
# owl : 1
# LOW : 1

# %%
def test_get_vocab():
  corpus = ['test']
  vocab = get_vocab(corpus)
  assert vocab == {("t", "e", "s", "t", ""):1}
  print("✓")

def test_get_status():
  vocab = {('t', 'e', 's', 't', '' ):1}
  stats = get_stats(vocab)
  expected = {
        ('t', 'e'): 1,
        ('e', 's'): 1,
        ('s', 't'): 1,
        ('t', ''): 1
  }
  assert stats == expected
  print("✓✓")

def test_merge_vocab():
  vocab = {('t', 'e', 's', 't', '' ):1}
  merged = merge_vocab(("e", "s"),vocab)
  print(merged)
  expected = {("t", "es", 't', ''):1}
  assert merged == expected
  print("✓✓✓")

def test_bpe_sequence():
  corpus = ['low', 'lower', 'lower', 'newest', 'wildest']
  final_vocab, merges = byte_pair_encoding(corpus, num_merges=5)
  assert isinstance(final_vocab, dict)
  assert all(isinstance(pair, tuple) for pair in merges)
  assert len(merges) == 5
  print("✓✓✓✓")

test_get_vocab()
test_get_status()
test_merge_vocab()
test_bpe_sequence()
# Out:
# ✓
# ✓✓
# Bigram: e s
# {('t', 'es', 't', ''): 1}
# ✓✓✓
# Bigram: l o
# Merge 1: ('l', 'o')
# Bigram: lo w
# Merge 2: ('lo', 'w')
# Bigram: low e
# Merge 3: ('low', 'e')
# Bigram: lowe r
# Merge 4: ('lowe', 'r')
# Bigram: lower
# Merge 5: ('lower', '')
# ✓✓✓✓
